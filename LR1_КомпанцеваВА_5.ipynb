# %% [markdown]
# # Лабораторная работа 1. Методы агрегации и группировки данных
#
# **Вариант 5.** Набор данных `visits.csv` — Данные пользовательских сессии магазина
#
# **Цель работы:** овладение навыками агрегации и группировки табличных
# данных для преобразования детальных записей в структурированные
# аналитические отчёты.

# %% [markdown]
# ## 1. Загрузка датасета
#
# Импортируем библиотеку pandas и загружаем данные из csv-файла.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/versanivc/LR/refs/heads/main/visits.csv'

# Чтение таблицы с разделителем ;
df = pd.read_csv(url, sep=';')

# %% [markdown]
# ## 2. Вывод первых 20 строк
#
# С помощью метода `head()` выводим первые 20 строк набора данных, чтобы составить общее впечатление о данных.

# %%
# Вывод первых 20 строк
df.head(20)
# Out:
#         User_Id         Region   Device       Channel     Session_Start  \
# 0   9,81449E+11  United States   iPhone       organic   01.05.2019 2:36
# 1   2,78966E+11  United States   iPhone       organic   01.05.2019 4:46
# 2   5,90706E+11  United States      Mac       organic  01.05.2019 14:09
# 3   3,26434E+11  United States  Android        TipTop   01.05.2019 0:29
# 4   3,49774E+11  United States      Mac       organic   01.05.2019 3:33
# 5   43958116050  United States  Android       organic   01.05.2019 9:03
# 6   1,85365E+11  United States   iPhone       organic   01.05.2019 9:37
# 7   1,00971E+11  United States      Mac        TipTop   01.05.2019 4:39
# 8   3,70456E+11  United States   iPhone       organic  01.05.2019 14:44
# 9   1,41838E+11  United States      Mac      FaceBoom   01.05.2019 6:20
# 10  9,24309E+11  United States   iPhone       organic  01.05.2019 20:03
# 11  7,74938E+11  United States   iPhone  MediaTornado  01.05.2019 14:01
# 12  2,44879E+11  United States   iPhone  MediaTornado   01.05.2019 1:59
# 13  1,57877E+11  United States      Mac       organic  01.05.2019 10:25
# 14  5,24629E+11  United States      Mac       organic  01.05.2019 17:06
# 15  1,36227E+11  United States       PC       organic  01.05.2019 19:34
# 16  6,84979E+11  United States   iPhone        TipTop   01.05.2019 1:51
# 17  9,05776E+11  United States   iPhone       organic  01.05.2019 14:26
# 18  15174034813  United States   iPhone      FaceBoom  01.05.2019 15:34
# 19  1,88246E+11  United States  Android      FaceBoom  01.05.2019 23:09
#
#          SESSION_End
# 0    01.05.2019 2:45
# 1    01.05.2019 4:47
# 2   01.05.2019 15:32
# 3    01.05.2019 0:54
# 4    01.05.2019 3:57
# 5   01.05.2019 10:08
# 6   01.05.2019 10:00
# 7    01.05.2019 4:57
# 8   01.05.2019 15:41
# 9    01.05.2019 6:54
# 10  01.05.2019 20:19
# 11  01.05.2019 14:29
# 12   01.05.2019 2:21
# 13  01.05.2019 10:35
# 14  01.05.2019 18:05
# 15  01.05.2019 19:39
# 16   01.05.2019 2:12
# 17  01.05.2019 14:35
# 18  01.05.2019 15:56
# 19  01.05.2019 23:21

# %% [markdown]
# ## 3. Обзор данных - описание столбцов и предметной области
#
# Набор данных содержит информацию о пользовательских сессии магазина. Описание столбцов:
#
# - **User_Id** - уникальный идентификатор пользователя
# - **Region** -  страна пользователя
# - **Device** -  устройство пользователя
# - **Channel** - идентификатор рекламного источника, из которого пришел
# пользователь
# - **Session_Start** - дата и время начала сессии
# - **SESSION_End** - дата и время окончания сессии
#
#
# Предметная область — электронная коммерция. Данные могут использоваться для анализа поведения пользователей, продолжительности сессий, эффективности рекламных каналов, а также различий в активности пользователей в зависимости от региона и типа устройства.

# %% [markdown]
# ## 4. Оценка данных с помощью info()
#
# Метод `info()` предоставляет общую информацию о таблице: названия столбцов, типы данных, хранящиеся в них, и количество ненулевых значений в каждом столбце.

# %%
# Общая информация о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        957 non-null    object
#  1   Region         956 non-null    object
#  2   Device         955 non-null    object
#  3   Channel        957 non-null    object
#  4   Session_Start  955 non-null    object
#  5   SESSION_End    955 non-null    object
# dtypes: object(6)
# memory usage: 45.0+ KB

# %% [markdown]
# **Результаты:**
# - Всего строк: 957
# - Столбцов: 6
# - Обнаружены пропуски в столбцах: `Region` (1), `Device` (2), `Session_Start` (2), `SESSION_End` (2),
# - Без пропусков: `User_Id`, `Channel`
# - Типы данных: `object` (6)
#
# **Проблемы:**
# - `Session_Start` определён как `object` вместо даты и времени
# - `SESSION_End` определён как `object` вместо даты и времени
# - `SESSION_End` записан в верхнем регистре, в отличие от `Session_End`
# - Наличие пропусков требует обработки

# %% [markdown]
# ## 5. Применение describe()
#
# С помощью `describe()` оценим числовые столбцы: посмотрим на средние значения, минимум, максимум, стандартное отклонение и квартили.

# %%
# Статистика по числовым столбцам
df.describe()
# Out:
#             User_Id         Region  Device  Channel    Session_Start  \
# count           957            956     955      957              955
# unique          865              2       6        4              820
# top     1,79085E+11  United States  iPhone  organic  02.05.2019 9:40
# freq              4            955     421      612                4
#
#              SESSION_End
# count                955
# unique               836
# top     02.05.2019 22:49
# freq                   3

# %% [markdown]
# С помощью `describe()` оценены числовые столбцы:
#
# - **User_Id:** всего 957 записей, из них 865 уникальных пользователей. Некоторые пользователи посещали сайт несколько раз.
# - **Region:** пользователи представлены из 2 стран, при этом почти все записи относятся к United States.
# - **Device:** в данных присутствует 6 типов устройств. Наиболее популярное устройство — iPhone, встречается 421 раз.
# - **Channel:** используется 4 рекламных канала. Чаще всего пользователи приходят через канал organic — 612 сессий.
# - **Session_Start:** зафиксировано 820 уникальных моментов начала сессий, некоторые даты и время повторяются.
# - **SESSION_End:** присутствует 836 уникальных значений времени окончания сессий.

# %% [markdown]
# ## 6. Проверка названий столбцов
#
# Выведем названия столбцов с помощью `df.columns` и проверим, есть ли проблемы: пробелы в названиях, разные языки, непонятные названия.

# %%
# Вывод названий столбцов
print(df.columns.tolist())
# Out:
# ['User_Id', 'Region', 'Device', 'Channel', 'Session_Start', 'SESSION_End']

# %% [markdown]
# Как видно выше, названия столбцов в целом оформлены корректно: отсутствуют пробелы, большинство столбцов придерживаются единого стиля именования. Однако наблюдается небольшое несоответствие — столбец SESSION_End записан в верхнем регистре, в отличие от остальных названий. После приведения к единому стилю он был приведён к виду Session_End.

# %%
# Переименование отдельных столбцов
df = df.rename(columns={'SESSION_End': 'Session_End'})

# Вывод названий столбцов
print(df.columns.tolist())
# Out:
# ['User_Id', 'Region', 'Device', 'Channel', 'Session_Start', 'Session_End']

# %% [markdown]
# С помощью метода `rename()` столбец `SESSION_End` был переименован в `Session_End`. Теперь названия столбцов приведены к единому стилю: отсутствуют пробелы, имена оформлены в согласованном формате, а также являются понятными и отражают суть данных.

# %% [markdown]
# ## 7. Проверка данных на наличие пропусков
#
# Для нахождения пропусков применяется метод `isna()`. Потом результат работы `isna()` передаём методу `sum()`.

# %%
# Подсчёт количества пропусков в каждом столбце
print(df.isna().sum())
# Out:
# User_Id          0
# Region           1
# Device           2
# Channel          0
# Session_Start    2
# Session_End      2
# dtype: int64

# %% [markdown]
# В результате проверки обнаружены пропуски в 4 столбцах:
# - `Region` - 1 пропуск
# - `Device` - 2 пропуска
# - `Session_Start` - 2 пропуска
# - `Session_End ` - 2 пропуска
#
# Способ обработки пропусков зависит от их типа и значимости столбца:
# - Строки без данных в столбцах  (`Session_Start` и `Session_End`) удалены, так как без этой информации запись теряет смысл.
# - Пропуски в столбцах (`Region` и `Device`) заполним пропущенные значения наиболее часто встречающимися значениями в таблице. - это позволяет сохранить строки и не исказить общее распределение значений.

# %%
# 1. Удаляем строки, где пропущено начало и конец сессии
df = df.dropna(subset=['Session_Start'])
df = df.dropna(subset=['Session_End'])
# 2. Заполняем столбцы  Регион и Столбец наиболее часто
# встречающимися значениями в таблице
df['Region'] = df['Region'].fillna(df['Region'].mode()[0])
df['Device'] = df['Device'].fillna(df['Device'].mode()[0])


# 4. Проверяем, что пропусков не осталось
print(df.isna().sum())
# Out:
# User_Id          0
# Region           0
# Device           0
# Channel          0
# Session_Start    0
# Session_End      0
# dtype: int64

# %% [markdown]
# Пропуски успешно обработаны. Во всех столбцах количество пропусков - 0. Данные готовы к дальнейшей проверке.

# %% [markdown]
# ## 8. Проверка данных на наличие дубликатов
#
# Проверим явные и неявные дубликаты. Для поиска явных дубликатов используется метод `duplicated()`.

# %%
# Поиск и подсчёт явных дубликатов
print('Количество дубликатов:', df.duplicated().sum())

# Вывод строк-дубликатов
print('\nСтроки-дубликаты:')
display(df[df.duplicated()])

# Удаление дубликатов и обновление индексации
df = df.drop_duplicates().reset_index(drop=True)

# Проверяем, что дубликатов не осталось
print('\nКоличество дубликатов после удаления:', df.duplicated().sum())
# Out:
# Количество дубликатов: 2
#
# Строки-дубликаты:
#          User_Id         Region Device  Channel    Session_Start  \
# 480  1,79085E+11  United States    Mac  organic  01.05.2019 7:27
# 481  1,79085E+11  United States    Mac  organic  01.05.2019 7:27
#
#          Session_End
# 480  01.05.2019 7:49
# 481  01.05.2019 7:49
# Количество дубликатов после удаления: 0

# %% [markdown]
# Для поиска неявных дубликатов — смотрим уникальные значения в текстовых столбцах

# %%
# Поиск неявных дубликатов: смотрим уникальные значения в  столбцах
print('Уникальные значения в столбце "Region":')
print(df['Region'].unique())

print('\nУникальные значения в столбце "Device":')
print(df['Device'].unique())

print('\nУникальные значения в столбце "Channel":')
print(df['Channel'].unique())
# Out:
# Уникальные значения в столбце "Region":
# ['United States' 'USA']
#
# Уникальные значения в столбце "Device":
# ['iPhone' 'Mac' 'Android' 'PC' 'MAC' 'IPHONE']
#
# Уникальные значения в столбце "Channel":
# ['organic' 'TipTop' 'FaceBoom' 'MediaTornado']

# %% [markdown]
# Приведено приведение значений столбцов `Region` и `Device` к единому формату с использованием функции `replace()`

# %%
# Приводим значения столбца Region к единому формату:
# заменяем сокращение 'USA' на полное название 'United States'
df['Region'] = df['Region'].replace('USA', 'United States')
# Приводим значения столбца Device к единому стилю написания:
# заменяем некорректные/разные варианты названий устройств на стандартные
df['Device'] = df['Device'].replace({
'MAC': 'Mac','IPHONE': 'iPhone'})
# Проверяем
print(df['Region'].unique())
print(df['Device'].unique())
# Out:
# ['United States']
# ['iPhone' 'Mac' 'Android' 'PC']

# %% [markdown]
# **Явные дубликаты.** С помощью метода `duplicated()` было обнаружено 2 повторяющиеся строки (один пользователь с одной датой начала сессии — 01.05.2019 7:27 — встречается дважды). Дубликаты были удалены с помощью метода `drop_duplicates()` с обновлением индексации.
#
# **Неявные дубликаты.** С помощью метода `unique()` в столбцах `Region` и `Device` были выявлены несогласованные записи. В столбце `Region` сокращение `USA` было заменено на полное название `United States` с помощью метода `replace()`. В столбце `Device` значения `MAC` и `IPHONE` были приведены к единому формату (`Mac` и `iPhone` соответственно) также с использованием `replace()`.
#
# После преобразований проверка методом `unique()` показала, что значения стандартизированы. В столбце `Channe` неявных дубликатов обнаружено не было.

# %% [markdown]
# ## 9. Проверка типов данных
#
# Проверим типы данных в столбцах и при необходимости изменим их, чтобы они соответствовали действительности.

# %%
# Проверка текущих типов данных
print(df.dtypes)
# Out:
# User_Id          object
# Region           object
# Device           object
# Channel          object
# Session_Start    object
# Session_End      object
# dtype: object

# %% [markdown]
# Столбцы `Session_Start` и `Session_End` имеют тип `object`, хотя должны быть в формат даты и времени (datetime)

# %%
# Приведение к формату даты и времени
df['Session_Start'] = pd.to_datetime(df['Session_Start'], format='%d.%m.%Y %H:%M')
df['Session_End'] = pd.to_datetime(df['Session_End'], format='%d.%m.%Y %H:%M')
# Проверяем результат
print(df.dtypes)
# Out:
# User_Id                  object
# Region                   object
# Device                   object
# Channel                  object
# Session_Start    datetime64[ns]
# Session_End      datetime64[ns]
# dtype: object

# %% [markdown]
# ## 10. Выводы по работе
#
# По итогам выполнения контрольной работы был проведён полный цикл предварительного анализа и очистки набора данных `visits.csv`, содержащего информацию о пользовательских сессиях интернет-магазина.
#
# В процессе работы были последовательно решены следующие задачи: загрузка данных с корректным указанием разделителя, первичный визуальный осмотр первых 20 строк, анализ структуры таблицы с помощью `info()` и `describe()`. В ходе анализа выявлены и устранены типичные проблемы исходных данных: некорректные типы данных в столбцах с датой и временем, пропуски значений в столбцах `Region`, `Device`, `Session_Start`, `Session_End`, явные дубликаты строк, а также неявные дубликаты, связанные с несогласованным написанием значений в категориальных переменных (`USA / United States`, `MAC / Mac`, `IPHONE / iPhone`). Дополнительно приведено к единому стилю название столбца `SESSION_End`.
#
# Для обработки пропусков использовались удаление строк с критическими пропусками и заполнение модальными значениями. Дубликаты удалены, а категориальные переменные стандартизированы. Типы данных столбцов `Session_Start` и `Session_End` успешно преобразованы в формат `datetime`.
#
# В результате получен очищенный, структурированный и готовый к дальнейшему анализу набор данных, что подтверждает достижение цели работы и освоение ключевых методов предобработки данных с использованием библиотеки pandas.

# %% [markdown]
# ##**Группировка данных и построение сводных таблиц**

# %% [markdown]
# ##Задание 1 : Группировка - `device` и количество рекламных источников каждого типа (`channel`).

# %%
# Группировка по устройству и каналу с подсчетом количества
task1=df.groupby(['Device']).size().reset_index(name='count_channel')
print(task1)
# Out:
#     Device  count_channel
# 0  Android            185
# 1      Mac            242
# 2       PC            103
# 3   iPhone            423

# %% [markdown]
# Из полученной таблицы видно, что наибольшее количество сессий приходится на (`organic`) трафик для всех типов устройств. `iPhone` лидирует по количеству сессий (422), за ним следует `Mac` (242). Наименьшее количество сессий зафиксировано для `PC` через канал `MediaTornado` (всего 2 сессии).
# Это позволяет сделать вывод о том, что мобильные устройства являются основными для пользователей, а основной источник трафика – `organic`

# %% [markdown]
# ##Задание 2 : Группировка - `region` и количество устройств (`device`).Создать датафрейм. Переименовать столбец с количеством в “сount”. Отсортировать по убыванию столбца “count”.

# %%
task2= (
    df.groupby(['Region', 'Device'])
      .size()
      .reset_index(name='count')
      .sort_values(by='count', ascending=False)
)
print(task2)
# Out:
#           Region   Device  count
# 3  United States   iPhone    423
# 1  United States      Mac    242
# 0  United States  Android    185
# 2  United States       PC    103

# %% [markdown]
# Как видно из данных, в регионе `США` наибольшую активность демонстрируют пользователи, заходящие с устройств `iPhone` — 423 пользователя. На втором месте находятся устройства Mac — `242` пользователя.
# Это показывает, что большинство пользователей из `США` заходят с техники `Apple`, особенно с `iPhone`.

# %% [markdown]
# ##Задание 3 :  Сводная таблица (`pivot_table`) - уникальное количество пользователей для каждого устройства (`device`). Отсортировать по убыванию количества

# %%
task3= df.pivot_table(index='Device',
                      values='User_Id',
                      aggfunc='nunique').reset_index().sort_values(by='User_Id', ascending=False)
print(task3)
# Out:
#     Device  User_Id
# 3   iPhone      385
# 1      Mac      223
# 0  Android      169
# 2       PC       90

# %% [markdown]
# В рамках анализа была сформирована сводная таблица `data_pivot`, которая позволяет оценить распределение пользователей в электронной коммерции по типам устройств.
#
# Наиболее популярным устройством является `iPhone` (385 пользователей). Далее следуют `Mac` (223 пользователя), `Android` (169 пользователей) и `PC` (90 пользователей).

# %% [markdown]
# ##Задание 4 :   Сводная таблица (pivot_table) - уникальное количество пользователей для каждого устройства (device) - столбцы и региона- строки. Отсортировать по возрастанию столбца region.

# %%
pivot_users= df.pivot_table(
    index='Region',
    columns='Device',
    values='User_Id',
    aggfunc='nunique').sort_index()
print(pivot_users)
# Out:
# Device         Android  Mac  PC  iPhone
# Region
# United States      169  223  90     385

# %% [markdown]
# Видно, что основная пользовательская активность сосредоточена на устройствах `Apple`, особенно на `iPhone`, что подтверждает преобладание мобильного поведения в электронной коммерции.

# %% [markdown]
# ##Задание 5 :   Добавить столбец - “Длительность сессии” (расчетный). Создать столбец “Категория длительности” (с помощью категоризации). Выделить минимум 3 категории (низкая, высокая, средняя), фильтрацию для уровня длительности выбрать самостоятельно, аргументировать выбор. Создать группировку: средняя, минимальная, максимальная, медианная длительность сессии по категории длительности и устройству

# %%
df['Session_duration'] = df['Session_End'] - df['Session_Start']
print(df)
# Out:
#          User_Id         Region   Device   Channel       Session_Start  \
# 0    9,81449E+11  United States   iPhone   organic 2019-05-01 02:36:00
# 1    2,78966E+11  United States   iPhone   organic 2019-05-01 04:46:00
# 2    5,90706E+11  United States      Mac   organic 2019-05-01 14:09:00
# 3    3,26434E+11  United States  Android    TipTop 2019-05-01 00:29:00
# 4    3,49774E+11  United States      Mac   organic 2019-05-01 03:33:00
# ..           ...            ...      ...       ...                 ...
# 948  5,55066E+11  United States   iPhone    TipTop 2019-05-04 23:32:00
# 949  7,71716E+11  United States  Android    TipTop 2019-05-04 19:32:00
# 950  74352279110  United States   iPhone    TipTop 2019-05-04 00:13:00
# 951  6,08683E+11  United States  Android  FaceBoom 2019-05-04 03:33:00
# 952  8,75326E+11  United States      Mac   organic 2019-05-04 03:01:00
#
#             Session_End Session_duration
# 0   2019-05-01 02:45:00  0 days 00:09:00
# 1   2019-05-01 04:47:00  0 days 00:01:00
# 2   2019-05-01 15:32:00  0 days 01:23:00
# 3   2019-05-01 00:54:00  0 days 00:25:00
# 4   2019-05-01 03:57:00  0 days 00:24:00
# ..                  ...              ...
# 948 2019-05-04 23:38:00  0 days 00:06:00
# 949 2019-05-04 19:48:00  0 days 00:16:00
# 950 2019-05-04 00:26:00  0 days 00:13:00
# 951 2019-05-04 03:46:00  0 days 00:13:00
# 952 2019-05-04 03:15:00  0 days 00:14:00
#
# [953 rows x 7 columns]

# %% [markdown]
# Добавлен новый столбец «Длительность сессии» и заполнены данные для категории длительности.
# Категории длительности выбраны следующим образом:
#
# *  до 10 минут — низкая длительность;
# *   от 10 до 20 минут — средняя;
# *  более 20 минут — высокая.
#
# Такое разделение позволяет выделить короткие, стандартные и длительные пользовательские сессии.

# %%
bins=[pd.Timedelta('0 days 00:00:00'), pd.Timedelta('0 days 00:10:00'),
      pd.Timedelta('0 days 00:20:00'), pd.Timedelta('0 days 02:00:00') ] # границы
labels = ['Низкая', 'Средняя', 'Высокая']

df['Duration_Category'] = pd.cut(df['Session_duration'], bins=bins, labels=labels)

task4=df.groupby(['Device','Duration_Category']).agg({'Session_duration':['mean','min','max','median']}).reset_index()
print(task4)
# Out:
#      Device Duration_Category          Session_duration                  \
#                                                    mean             min
# 0   Android            Низкая 0 days 00:05:19.534883720 0 days 00:01:00
# 1   Android           Средняя           0 days 00:14:27 0 days 00:11:00
# 2   Android           Высокая 0 days 00:48:35.049504950 0 days 00:21:00
# 3       Mac            Низкая           0 days 00:06:00 0 days 00:01:00
# 4       Mac           Средняя 0 days 00:15:48.196721311 0 days 00:11:00
# 5       Mac           Высокая 0 days 00:46:37.894736842 0 days 00:21:00
# 6        PC            Низкая 0 days 00:05:17.142857142 0 days 00:01:00
# 7        PC           Средняя 0 days 00:15:46.363636363 0 days 00:11:00
# 8        PC           Высокая           0 days 00:46:45 0 days 00:21:00
# 9    iPhone            Низкая 0 days 00:04:39.173553719 0 days 00:01:00
# 10   iPhone           Средняя 0 days 00:15:06.428571428 0 days 00:11:00
# 11   iPhone           Высокая 0 days 00:45:48.909952606 0 days 00:21:00
#
#
#                max          median
# 0  0 days 00:10:00 0 days 00:05:00
# 1  0 days 00:20:00 0 days 00:14:00
# 2  0 days 01:54:00 0 days 00:43:00
# 3  0 days 00:10:00 0 days 00:06:30
# 4  0 days 00:20:00 0 days 00:16:00
# 5  0 days 01:55:00 0 days 00:40:30
# 6  0 days 00:10:00 0 days 00:04:30
# 7  0 days 00:20:00 0 days 00:16:30
# 8  0 days 01:34:00 0 days 00:43:00
# 9  0 days 00:10:00 0 days 00:04:00
# 10 0 days 00:20:00 0 days 00:15:00
# 11 0 days 01:53:00 0 days 00:40:00
# /tmp/ipykernel_2382/1480256983.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   task4=df.groupby(['Device','Duration_Category']).agg({'Session_duration':['mean','min','max','median']}).reset_index()

# %% [markdown]
# В ходе анализа было выявлено, что пользователи PC проводят в сессиях больше времени, особенно в категории высокой длительности. Пользователи iPhone имеют самые короткие сессии в категории низкой длительности. Средние и медианные значения близки друг к другу, поэтому данные распределены достаточно равномерно. Категории длительности были выбраны корректно и позволяют разделить сессии на короткие, средние и длинные.

# %% [markdown]
# ##Задание 6 :   Добавить столбец - “Длительность сессии” (расчетный). Создать столбец “Категория длительности” (с помощью категоризации). Выделить минимум 3 категории (низкая,высокая, средняя), фильтрацию для уровня длительности выбрать самостоятельно, аргументировать выбор. Отфильтровать набор данных. Выбрать только высокую и низкую длительность сессии + 2 самых не популярных канала (по количеству записей). Создать сводную таблицу: средняя, медианная длительность сессии по каналу и устройству.

# %%
task6=df[df['Duration_Category'].isin(['Низкая','Высокая'])]
print(task6)
# Out:
#          User_Id         Region   Device  Channel       Session_Start  \
# 0    9,81449E+11  United States   iPhone  organic 2019-05-01 02:36:00
# 1    2,78966E+11  United States   iPhone  organic 2019-05-01 04:46:00
# 2    5,90706E+11  United States      Mac  organic 2019-05-01 14:09:00
# 3    3,26434E+11  United States  Android   TipTop 2019-05-01 00:29:00
# 4    3,49774E+11  United States      Mac  organic 2019-05-01 03:33:00
# ..           ...            ...      ...      ...                 ...
# 943  64474110919  United States   iPhone  organic 2019-05-04 00:24:00
# 945  8,61181E+11  United States      Mac  organic 2019-05-04 07:52:00
# 946  4,10845E+11  United States  Android   TipTop 2019-05-04 05:26:00
# 947  6,86573E+11  United States  Android   TipTop 2019-05-04 17:42:00
# 948  5,55066E+11  United States   iPhone   TipTop 2019-05-04 23:32:00
#
#             Session_End Session_duration Duration_Category
# 0   2019-05-01 02:45:00  0 days 00:09:00            Низкая
# 1   2019-05-01 04:47:00  0 days 00:01:00            Низкая
# 2   2019-05-01 15:32:00  0 days 01:23:00           Высокая
# 3   2019-05-01 00:54:00  0 days 00:25:00           Высокая
# 4   2019-05-01 03:57:00  0 days 00:24:00           Высокая
# ..                  ...              ...               ...
# 943 2019-05-04 00:58:00  0 days 00:34:00           Высокая
# 945 2019-05-04 08:01:00  0 days 00:09:00            Низкая
# 946 2019-05-04 06:19:00  0 days 00:53:00           Высокая
# 947 2019-05-04 18:06:00  0 days 00:24:00           Высокая
# 948 2019-05-04 23:38:00  0 days 00:06:00            Низкая
#
# [728 rows x 8 columns]

# %% [markdown]
# Ранее в задании 5 был создан столбец «Длительность сессии» (расчетный). Также был добавлен столбец «Категория длительности» с использованием категоризации, где выделены минимум три категории: низкая, средняя и высокая.
#
# Также была проведена фильтрация данных. А именно, были отобраны только записи с высокой и низкой длительностью сессии.

# %%
# Считаем количество записей по каждому каналу
channel_count=df['Channel'].value_counts()
print("Популярность каналов:")
print(channel_count)
# Берем 2 самых НЕпопулярных (с наименьшим количеством)
least_popular=channel_count.tail(2).index.tolist()

print("\n2 самых НЕпопулярных канала:")
print(least_popular)
task6 = df[df['Channel'].isin(least_popular)]
print("\n")
result = pd.pivot_table(
    task6,
    index='Channel',
    columns='Device',
    values='Session_duration',
    aggfunc=['mean', 'median']
)

print(result)
# Out:
# Популярность каналов:
# Channel
# organic         609
# FaceBoom        149
# TipTop          142
# MediaTornado     53
# Name: count, dtype: int64
#
# 2 самых НЕпопулярных канала:
# ['TipTop', 'MediaTornado']
#
#
#                                   mean                                  \
# Device                         Android             Mac              PC
# Channel
# MediaTornado 0 days 00:20:27.272727272 0 days 00:25:54 0 days 00:09:00
# TipTop       0 days 00:29:57.692307692 0 days 00:26:05 0 days 00:32:30
#
#                                                 median                  \
# Device                          iPhone         Android             Mac
# Channel
# MediaTornado           0 days 00:23:10 0 days 00:13:00 0 days 00:24:00
# TipTop       0 days 00:26:50.769230769 0 days 00:24:30 0 days 00:16:30
#
#
# Device                    PC          iPhone
# Channel
# MediaTornado 0 days 00:09:00 0 days 00:24:00
# TipTop       0 days 00:27:30 0 days 00:21:30

# %% [markdown]
# Из полученной сводной таблицы видно, что у двух наименее популярных каналов — `TipTop` и `MediaTornado` — заметно различается поведение пользователей в зависимости от устройства. `MediaTornado` в среднем показывает более короткие сессии на `Android` и особенно на `ПК`, тогда как на `Mac` и `iPhone` время выше и более стабильное. При этом медианные значения подтверждают, что на `ПК` и `Android` сессии чаще всего короче, чем на других устройствах.
#
# У `TipTop` общая длительность сессий выше и более равномерная между устройствами, особенно на `ПК`, где среднее время заметно выше остальных платформ. В целом, можно сказать, что `TipTop` удерживает пользователей стабильнее, тогда как `MediaTornado` демонстрирует более слабую вовлечённость, особенно на десктопных устройствах.

# %% [markdown]
# ##Задание 7 :   Проанализировать среднюю и медианную длительность сессий пользователей в зависимости от рекламного канала, но только для мобильных устройств (Android и iPhone). Необходимо отфильтровать данные по устройствам, затем построить сводную таблицу с группировкой по каналу и устройству

# %%
# фильтруем только мобильные устройства
task7 = df[df['Device'].isin(['Android','PC'])]
# строим сводную таблицу
result_task7 = pd.pivot_table( task7,
    index='Channel',
    columns='Device',
    values='Session_duration',
    aggfunc=['mean','median']
)
print(result_task7)
# Out:
#                                   mean                            \
# Device                         Android                        PC
# Channel
# FaceBoom     0 days 00:28:25.454545454           0 days 00:32:20
# MediaTornado 0 days 00:20:27.272727272           0 days 00:09:00
# TipTop       0 days 00:29:57.692307692           0 days 00:32:30
# organic                0 days 00:32:48 0 days 00:30:13.333333333
#
#                       median
# Device               Android              PC
# Channel
# FaceBoom     0 days 00:23:00 0 days 00:20:00
# MediaTornado 0 days 00:13:00 0 days 00:09:00
# TipTop       0 days 00:24:30 0 days 00:27:30
# organic      0 days 00:22:00 0 days 00:19:30

# %% [markdown]
# Из полученной сводной таблицы видно, что длительность сессий заметно различается в зависимости от рекламного канала и устройства. Наиболее стабильное поведение пользователей наблюдается у канала `MediaTornado` на `PC`, где средние и медианные значения совпадают и остаются низкими(9 минут), что говорит о коротких и однотипных сессиях.
#
# В каналах `organic`, `FaceBoom` и `TipTop` средняя длительность сессий выше медианы, что указывает на наличие отдельных длинных сессий, увеличивающих среднее значение и свидетельствующих о более разнообразном поведении пользователей. В целом, пользователи `PC` и `Android` демонстрируют схожие паттерны, однако в отдельных каналах (особенно `organi`) наблюдается более высокая вовлечённость и разброс по времени сессий.

# %% [markdown]
# ##Вывод:
# По итогам работы выполнена полная очистка данных: устранены пропуски, дубликаты и несогласованности в названиях, а также исправлены типы данных для столбцов с датой и временем.
#
# С помощью группировок и сводных таблиц выявлено, что большинство сессий приходится на iPhone и органический трафик, а основная активность пользователей сосредоточена в США. Анализ длительности сессий показал, что владельцы iPhone чаще имеют короткие сессии, тогда как пользователи PC проводят время дольше. Наименее популярные каналы (TipTop и MediaTornado) демонстрируют разную вовлечённость в зависимости от устройства, а на мобильных устройствах органический трафик и FaceBoom обеспечивают более высокую длительность взаимодействия.
